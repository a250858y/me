# %%
import pandas as pd

emdat=pd.read_csv("emdat.csv")
emdat.head()

# %%
import pandas as pd

df = pd.read_csv("emdat.csv")  # ファイル読み込み
unique_types = df["Disaster Type"].dropna().unique()
print("種類数:", len(unique_types))
print("種類一覧:", unique_types)

# %%
unique_types = df["Disaster Subtype"].dropna().unique()
print("種類数:", len(unique_types))
print("種類一覧:", unique_types)
